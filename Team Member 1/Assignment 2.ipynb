# %%
import pandas as pd

# %% [markdown]
# ##Load the data set

# %%
data = pd.read_csv("/content/drive/MyDrive/Churn_Modelling.csv")

# %% [markdown]
# ##Descriptive statistics on the dataset

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# ##Checking for missing value

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ##Visualization

# %%
import seaborn as sns

# %%
sns.lmplot(x='CreditScore', y='EstimatedSalary', hue='Exited', fit_reg=False, data=data)

# %%
sns.lmplot(x='CreditScore', y='Balance', hue='Exited', fit_reg=False, data=data)

# %%
sns.lmplot(x='Balance', y='EstimatedSalary', hue='Exited', fit_reg=False, data=data)

# %%
sns.pairplot(hue='Exited', data = data)

# %%
import matplotlib.pyplot as plt

# %%
correlation_metrics = data.corr()
fig = plt.figure(figsize=(14,9))
sns.heatmap(correlation_metrics, square = True)
plt.show()
print(correlation_metrics)
# Out:
#                  RowNumber  CustomerId  CreditScore  Geography    Gender  \
# RowNumber         1.000000    0.004202     0.005139  -0.010358  0.018196
# CustomerId        0.004202    1.000000     0.007237   0.006516 -0.002641
# CreditScore       0.005139    0.007237     1.000000   0.008934 -0.003609
# Geography        -0.010358    0.006516     0.008934   1.000000  0.004719
# Gender            0.018196   -0.002641    -0.003609   0.004719  1.000000
# Age              -0.003840    0.008541    -0.012507   0.027892 -0.030544
# Tenure           -0.006495   -0.014883    -0.000642   0.003739  0.014733
# Balance          -0.009067   -0.012419     0.007070   0.069408  0.012087
# NumOfProducts     0.006043    0.023350     0.010999   0.007892 -0.013450
# HasCrCard         0.000599   -0.014025    -0.003950  -0.008523  0.005766
# IsActiveMember    0.012044    0.001665     0.023607   0.006724  0.022544
# EstimatedSalary  -0.005988    0.015271     0.001604  -0.001369 -0.008112
# ...

# %%
sns.boxplot(data['CreditScore'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['EstimatedSalary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data['Balance'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.histplot(data["CreditScore"])

# %%
sns.lineplot(x="CreditScore", y="EstimatedSalary",
             data=data)

# %%
data['Surname'].unique().shape
# Out:
# (2932,)

# %%
data['Surname'].value_counts()
# Out:
# Smith       32
# Scott       29
# Martin      29
# Walker      28
# Brown       26
#             ..
# Izmailov     1
# Bold         1
# Bonham       1
# Poninski     1
# Burbidge     1
# Name: Surname, Length: 2932, dtype: int64

# %%
data['EstimatedSalary'].max()
# Out:
# 199992.48

# %%
data['EstimatedSalary'].min()
# Out:
# 11.58

# %% [markdown]
# ##finding and replacing the outliers

# %%
qnt = data.iloc[:,2:-1].quantile(q=[0.25, 0.75])

# %%
qnt
# Out:
#       CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0.25        584.0  32.0     3.0       0.00            1.0        0.0
# 0.75        718.0  44.0     7.0  127644.24            2.0        1.0
#
#       IsActiveMember  EstimatedSalary
# 0.25             0.0       51002.1100
# 0.75             1.0      149388.2475

# %%
IQR = qnt.loc[0.75] - qnt.loc[0.25]

# %%
IQR
# Out:
# CreditScore           134.0000
# Age                    12.0000
# Tenure                  4.0000
# Balance            127644.2400
# NumOfProducts           1.0000
# HasCrCard               1.0000
# IsActiveMember          1.0000
# EstimatedSalary     98386.1375
# dtype: float64

# %%
upper_extreme = qnt.loc[0.75]+1.5*IQR
upper_extreme
# Out:
# CreditScore           919.00000
# Age                    62.00000
# Tenure                 13.00000
# Balance            319110.60000
# NumOfProducts           3.50000
# HasCrCard               2.50000
# IsActiveMember          2.50000
# EstimatedSalary    296967.45375
# dtype: float64

# %%
print(data[data['CreditScore']>919].shape)
print(data[data['Age']>62].shape)#359 outlier data
print(data[data['Tenure']>13].shape)
print(data[data['Balance']>319110].shape)
print(data[data['NumOfProducts']>3.50].shape)
print(data[data['HasCrCard']>2.50].shape)
print(data[data['EstimatedSalary']>296967.45375].shape)
# Out:
# (0, 14)
# (359, 14)
# (0, 14)
# (0, 14)
# (60, 14)
# (0, 14)
# (0, 14)

# %%
lower_extreme = qnt.loc[0.25]-1.5*IQR
lower_extreme
# Out:
# CreditScore           383.00000
# Age                    14.00000
# Tenure                 -3.00000
# Balance           -191466.36000
# NumOfProducts          -0.50000
# HasCrCard              -1.50000
# IsActiveMember         -1.50000
# EstimatedSalary    -96577.09625
# dtype: float64

# %%
print(data[data['CreditScore']<383].shape) #there are 15 outlier data
print(data[data['Age']<14].shape)
print(data[data['Tenure']<-3].shape)
print(data[data['Balance']<-191466.36].shape)
print(data[data['NumOfProducts']<-0.5].shape)
print(data[data['HasCrCard']<-1.5].shape)
print(data[data['EstimatedSalary']<-96577.09625].shape)
# Out:
# (15, 14)
# (0, 14)
# (0, 14)
# (0, 14)
# (0, 14)
# (0, 14)
# (0, 14)

# %%
data1 = data
data1['CreditScore'].mean()
# Out:
# 650.9625932

# %%
import numpy as np

# %%
data1['CreditScore'] = np.where(data1['CreditScore']<383, data1['CreditScore'].mean(), data1['CreditScore'] )
data1
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1    15634602   Hargrave        619.0    France  Female  42.0
# 1             2    15647311       Hill        608.0     Spain  Female  41.0
# 2             3    15619304       Onio        502.0    France  Female  42.0
# 3             4    15701354       Boni        699.0    France  Female  39.0
# 4             5    15737888   Mitchell        850.0     Spain  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996    15606229   Obijiaku        771.0    France    Male  39.0
# 9996       9997    15569892  Johnstone        516.0    France    Male  35.0
# 9997       9998    15584532        Liu        709.0    France  Female  36.0
# 9998       9999    15682355  Sabbatini        772.0   Germany    Male  42.0
# 9999      10000    15628319     Walker        792.0    France  Female  28.0
#
# ...

# %%
data1['Age'] = np.where(data1['Age']>62, data1['Age'].mean(), data1['Age'] )
data1['NumOfProducts'] = np.where(data1['NumOfProducts']>3.50, data1['NumOfProducts'].mean(), data1['NumOfProducts'] )
data1
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1    15634602   Hargrave        619.0    France  Female  42.0
# 1             2    15647311       Hill        608.0     Spain  Female  41.0
# 2             3    15619304       Onio        502.0    France  Female  42.0
# 3             4    15701354       Boni        699.0    France  Female  39.0
# 4             5    15737888   Mitchell        850.0     Spain  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996    15606229   Obijiaku        771.0    France    Male  39.0
# 9996       9997    15569892  Johnstone        516.0    France    Male  35.0
# 9997       9998    15584532        Liu        709.0    France  Female  36.0
# 9998       9999    15682355  Sabbatini        772.0   Germany    Male  42.0
# 9999      10000    15628319     Walker        792.0    France  Female  28.0
#
# ...

# %% [markdown]
# ##Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbl = LabelEncoder()

# %%
data1['Geography'] = lbl.fit_transform(data['Geography'])
data1['Gender'] = lbl.fit_transform(data['Gender'])
data1.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender   Age  \
# 0          1    15634602  Hargrave     619.0000          0       0  42.0
# 1          2    15647311      Hill     608.0000          2       0  41.0
# 2          3    15619304      Onio     502.0000          0       0  42.0
# 3          4    15701354      Boni     699.0000          0       0  39.0
# 4          5    15737888  Mitchell     850.0000          2       0  43.0
# 5          6    15574012       Chu     645.0000          2       1  44.0
# 6          7    15592531  Bartlett     822.0000          0       1  50.0
# 7          8    15656148    Obinna     650.5288          1       0  29.0
# 8          9    15792365        He     501.0000          0       1  44.0
# 9         10    15592389        H?     684.0000          0       1  27.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00         1.0000          1               1
# ...

# %%
del data1['Surname'] #as we don't need name we can remove it as the result is not predicted by it

# %%
data1.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Geography  Gender   Age  Tenure  \
# 0          1    15634602        619.0          0       0  42.0       2
# 1          2    15647311        608.0          2       0  41.0       1
# 2          3    15619304        502.0          0       0  42.0       8
# 3          4    15701354        699.0          0       0  39.0       1
# 4          5    15737888        850.0          2       0  43.0       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00            1.0          1               1        101348.88
# 1   83807.86            1.0          0               1        112542.58
# 2  159660.80            3.0          1               0        113931.57
# 3       0.00            2.0          0               0         93826.63
# 4  125510.82            1.0          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %% [markdown]
# ##Spliting Dependent and Independent column

# %%
y = data1['Exited']
x = data1.iloc[:, 2:-1]

# %%
x
# Out:
#       CreditScore  Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0           619.0          0       0  42.0       2       0.00            1.0
# 1           608.0          2       0  41.0       1   83807.86            1.0
# 2           502.0          0       0  42.0       8  159660.80            3.0
# 3           699.0          0       0  39.0       1       0.00            2.0
# 4           850.0          2       0  43.0       2  125510.82            1.0
# ...           ...        ...     ...   ...     ...        ...            ...
# 9995        771.0          0       1  39.0       5       0.00            2.0
# 9996        516.0          0       1  35.0      10   57369.61            1.0
# 9997        709.0          0       0  36.0       7       0.00            1.0
# 9998        772.0          1       1  42.0       3   75075.31            2.0
# 9999        792.0          0       0  28.0       4  130142.79            1.0
#
# ...

# %% [markdown]
# ##Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaling = MinMaxScaler()

# %%
scaling.fit_transform(x[['CreditScore', 'Age', 'Balance', 'EstimatedSalary']])
# Out:
# array([[0.50535332, 0.54545455, 0.        , 0.50673489],
#        [0.48179872, 0.52272727, 0.33403148, 0.56270874],
#        [0.25481799, 0.54545455, 0.63635718, 0.56965435],
#        ...,
#        [0.69807281, 0.40909091, 0.        , 0.21039009],
#        [0.83297645, 0.54545455, 0.29922631, 0.46442905],
#        [0.875803  , 0.22727273, 0.51870777, 0.19091423]])

# %% [markdown]
# ##Spliting the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
x_train.shape
# Out:
# (7500, 10)

# %%
x_test.shape
# Out:
# (2500, 10)

# %%
y_train.shape
# Out:
# (7500,)

# %%
y_test.shape
# Out:
# (2500,)
